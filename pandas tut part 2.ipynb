# %% [markdown]
# # Filter multiple criteria

# %%
import pandas as pd
data=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')

# %%
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
data[(data.content_rating=="R") & (data.genre=='Crime')]
# Out:
#      star_rating                     title content_rating  genre  duration  \
# 0            9.3  The Shawshank Redemption              R  Crime       142
# 1            9.2             The Godfather              R  Crime       175
# 2            9.1    The Godfather: Part II              R  Crime       200
# 4            8.9              Pulp Fiction              R  Crime       154
# 21           8.7               City of God              R  Crime       130
# ..           ...                       ...            ...    ...       ...
# 927          7.5                     Brick              R  Crime       110
# 931          7.4              Mean Streets              R  Crime       112
# 950          7.4                     Bound              R  Crime       108
# 969          7.4       Law Abiding Citizen              R  Crime       109
# 978          7.4               Wall Street              R  Crime       126
#
#                                            actors_list
# ...

# %%
#1st method
data[(data.genre=='Crime') | (data.genre=='Action') | (data.genre=='Drama')]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %% [markdown]
# ## isin() function

# %%
#2nd method
data[data.genre.isin(['Crime','Drama','Action'])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# ...

# %% [markdown]
# # Selective columns and rows
#
#
# how can we restrict the number of rows and columns that we read from the dataset

# %%
data[['title','genre']]
# Out:
#                                                title      genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %%
data.loc[:4,:] #reading only first 5 rows
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# ## Iterating through our data within a series and dataframe

# %%
#iterating through series
for i in data.title:
    print(i)
# Out:
# The Shawshank Redemption
# The Godfather
# The Godfather: Part II
# The Dark Knight
# Pulp Fiction
# 12 Angry Men
# The Good, the Bad and the Ugly
# The Lord of the Rings: The Return of the King
# Schindler's List
# Fight Club
# The Lord of the Rings: The Fellowship of the Ring
# Inception
# Star Wars: Episode V - The Empire Strikes Back
# Forrest Gump
# The Lord of the Rings: The Two Towers
# Interstellar
# One Flew Over the Cuckoo's Nest
# Seven Samurai
# Goodfellas
# Star Wars
# The Matrix
# City of God
# It's a Wonderful Life
# The Usual Suspects
# Se7en
# Life Is Beautiful
# Once Upon a Time in the West
# The Silence of the Lambs
# Leon: The Professional
# City Lights
# Spirited Away
# The Intouchables
# Casablanca
# Whiplash
# American History X
# Modern Times
# Saving Private Ryan
# Raiders of the Lost Ark
# Rear Window
# Psycho
# The Green Mile
# Sunset Blvd.
# The Pianist
# The Dark Knight Rises
# Gladiator
# Terminator 2: Judgment Day
# Memento
# Taare Zameen Par
# ...

# %%
# iterating through dataframe
data=data[:10]
for index,row in data.iterrows():
    print(index,row.title,row.genre)
# Out:
# 0 The Shawshank Redemption Crime
# 1 The Godfather Crime
# 2 The Godfather: Part II Crime
# 3 The Dark Knight Action
# 4 Pulp Fiction Crime
# 5 12 Angry Men Drama
# 6 The Good, the Bad and the Ugly Western
# 7 The Lord of the Rings: The Return of the King Adventure
# 8 Schindler's List Biography
# 9 Fight Club Drama

# %% [markdown]
# # Axis parameter

# %%
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
data.mean() #by defualt it is taking axis=
# Out:
# star_rating      7.889785
# duration       120.979571
# dtype: float64

# %%
data.mean(axis=1)
# Out:
# 0       75.65
# 1       92.10
# 2      104.55
# 3       80.50
# 4       81.45
#         ...
# 974     61.70
# 975     62.70
# 976     72.70
# 977     60.70
# 978     66.70
# Length: 979, dtype: float64

# %% [markdown]
# # String methods in Pandas

# %%
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#applying function to the title series
data.title.str.upper()
# Out:
# 0                             THE SHAWSHANK REDEMPTION
# 1                                        THE GODFATHER
# 2                               THE GODFATHER: PART II
# 3                                      THE DARK KNIGHT
# 4                                         PULP FICTION
#                             ...
# 974                                            TOOTSIE
# 975                        BACK TO THE FUTURE PART III
# 976    MASTER AND COMMANDER: THE FAR SIDE OF THE WORLD
# 977                                        POLTERGEIST
# 978                                        WALL STREET
# Name: title, Length: 979, dtype: object

# %%
data.actors_list
# Out:
# 0      [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1        [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2      [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3      [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4      [u'John Travolta', u'Uma Thurman', u'Samuel L....
#                              ...
# 974    [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975    [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976    [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977    [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978    [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
# Name: actors_list, Length: 979, dtype: object

# %%
data.actors_list.str.replace('[','').str.replace(']','')
# Out:
# 0       u'Tim Robbins', u'Morgan Freeman', u'Bob Gunton'
# 1          u'Marlon Brando', u'Al Pacino', u'James Caan'
# 2      u'Al Pacino', u'Robert De Niro', u'Robert Duvall'
# 3      u'Christian Bale', u'Heath Ledger', u'Aaron Ec...
# 4      u'John Travolta', u'Uma Thurman', u'Samuel L. ...
#                              ...
# 974    u'Dustin Hoffman', u'Jessica Lange', u'Teri Garr'
# 975    u'Michael J. Fox', u'Christopher Lloyd', u'Mar...
# 976     u'Russell Crowe', u'Paul Bettany', u'Billy Boyd'
# 977    u'JoBeth Williams', u"Heather O'Rourke", u'Cra...
# 978    u'Charlie Sheen', u'Michael Douglas', u'Tamara...
# Name: actors_list, Length: 979, dtype: object

# %%
# contains method

data.title.str.contains("the")
# Out:
# 0      False
# 1       True
# 2       True
# 3      False
# 4      False
#        ...
# 974    False
# 975     True
# 976     True
# 977    False
# 978    False
# Name: title, Length: 979, dtype: bool

# %%
data[data.title.str.contains("the")]
# Out:
#      star_rating                                              title  \
# 1            9.2                                      The Godfather
# 2            9.1                             The Godfather: Part II
# 6            8.9                     The Good, the Bad and the Ugly
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# ..           ...                                                ...
# 923          7.5                                Across the Universe
# 930          7.4                                    Man on the Moon
# 932          7.4          Harry Potter and the Order of the Phoenix
# 975          7.4                        Back to the Future Part III
# 976          7.4    Master and Commander: The Far Side of the World
#
#     content_rating      genre  duration  \
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %% [markdown]
# # Changing the datatypes
#
# changing the datatypes of a particular series in a dataframe

# %%
data.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
#change the datatype of duration from integer to float
data.duration = data.duration.astype('float')

# %%
data.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration          float64
# actors_list        object
# dtype: object

# %%
data=pd.read_table('https://bit.ly/chiporders')

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.item_price.dtype
# Out:
# dtype('O')

# %%
data.item_price=data.item_price.str.replace("$",'')

# %%
data.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN      2.39
# 1                                       [Clementine]      3.39
# 2                                            [Apple]      3.39
# 3                                                NaN      2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...     16.98

# %%
data.item_price=data.item_price.astype('float')

# %%
data.item_price.mean()
# Out:
# 7.464335785374397

# %%
data.item_name.str.contains("and")
# Out:
# 0        True
# 1       False
# 2       False
# 3        True
# 4       False
#         ...
# 4617    False
# 4618    False
# 4619    False
# 4620    False
# 4621    False
# Name: item_name, Length: 4622, dtype: bool

# %%
data.item_name.str.contains("and").astype('int')
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 4617    0
# 4618    0
# 4619    0
# 4620    0
# 4621    0
# Name: item_name, Length: 4622, dtype: int32

# %% [markdown]
# # Groupby function

# %%
# in imdb dataset i want to check for different genre what is the mean or max, any aggergate duration

# %%
data=pd.read_csv('https://raw.githubusercontent.com/justmarkham/pandas-videos/master/data/imdb_1000.csv')
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
data.groupby('genre').duration.mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
data.groupby('genre').duration.min()
# Out:
# genre
# Action        80
# Adventure     89
# Animation     75
# Biography     85
# Comedy        68
# Crime         67
# Drama         64
# Family       100
# Fantasy      112
# Film-Noir     88
# History       66
# Horror        70
# Mystery       69
# Sci-Fi        91
# Thriller     107
# Western       85
# Name: duration, dtype: int64

# %%
data.groupby('genre').duration.agg(['min','max','mean','median','count'])
# Out:
#            min  max        mean  median  count
# genre
# Action      80  205  126.485294   125.0    136
# Adventure   89  224  134.840000   127.0     75
# Animation   75  134   96.596774    94.5     62
# Biography   85  202  131.844156   127.0     77
# Comedy      68  187  107.602564   104.0    156
# Crime       67  229  122.298387   118.0    124
# Drama       64  242  126.539568   123.0    278
# Family     100  115  107.500000   107.5      2
# Fantasy    112  112  112.000000   112.0      1
# Film-Noir   88  111   97.333333    93.0      3
# History     66   66   66.000000    66.0      1
# Horror      70  146  102.517241   104.0     29
# Mystery     69  160  115.625000   115.0     16
# Sci-Fi      91  132  109.000000   113.0      5
# Thriller   107  120  114.200000   116.0      5
# Western     85  175  136.666667   135.0      9

# %%
data.groupby('genre').agg(['min','max','median','count','mean'])
# Out:
#           star_rating                             duration                    \
#                   min  max median count      mean      min  max median count
# genre
# Action            7.4  9.0   7.80   136  7.884559       80  205  125.0   136
# Adventure         7.4  8.9   7.90    75  7.933333       89  224  127.0    75
# Animation         7.4  8.6   7.90    62  7.914516       75  134   94.5    62
# Biography         7.4  8.9   7.80    77  7.862338       85  202  127.0    77
# Comedy            7.4  8.6   7.80   156  7.822436       68  187  104.0   156
# Crime             7.4  9.3   7.80   124  7.916935       67  229  118.0   124
# Drama             7.4  8.9   7.90   278  7.902518       64  242  123.0   278
# Family            7.8  7.9   7.85     2  7.850000      100  115  107.5     2
# Fantasy           7.7  7.7   7.70     1  7.700000      112  112  112.0     1
# Film-Noir         7.7  8.3   8.10     3  8.033333       88  111   93.0     3
# ...

# %% [markdown]
# # Function on series

# %%
data.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
data.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Sci-Fi         5
# Thriller       5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
type(data.genre.value_counts())
# Out:
# pandas.core.series.Series

# %%
data.genre.value_counts().head()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Name: genre, dtype: int64

# %%
data.genre.value_counts(normalize=True) #distribution
# Out:
# Drama        0.283963
# Comedy       0.159346
# Action       0.138917
# Crime        0.126660
# Biography    0.078652
# Adventure    0.076609
# Animation    0.063330
# Horror       0.029622
# Mystery      0.016343
# Western      0.009193
# Sci-Fi       0.005107
# Thriller     0.005107
# Film-Noir    0.003064
# Family       0.002043
# History      0.001021
# Fantasy      0.001021
# Name: genre, dtype: float64

# %%
data.genre.value_counts(normalize=True).sum()
# Out:
# 1.0

# %%
data.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
data.genre.nunique()
# Out:
# 16

# %%
pd.crosstab(data.genre,data.content_rating)
#observation 25 drame movies are rated PG
# Out:
# content_rating  APPROVED   G  GP  NC-17  NOT RATED  PASSED  PG  PG-13    R  \
# genre
# Action                 3   1   1      0          4       1  11     44   67
# Adventure              3   2   0      0          5       1  21     23   17
# Animation              3  20   0      0          3       0  25      5    5
# Biography              1   2   1      0          1       0   6     29   36
# Comedy                 9   2   1      1         16       3  23     23   73
# Crime                  6   0   0      1          7       1   6      4   87
# Drama                 12   3   0      4         24       1  25     55  143
# Family                 0   1   0      0          0       0   1      0    0
# Fantasy                0   0   0      0          0       0   0      0    1
# Film-Noir              1   0   0      0          1       0   0      0    0
# History                0   0   0      0          0       0   0      0    0
# ...

# %% [markdown]
# # Plotting series in pandas

# %%
data.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
data.duration.describe()
# Out:
# count    979.000000
# mean     120.979571
# std       26.218010
# min       64.000000
# 25%      102.000000
# 50%      117.000000
# 75%      134.000000
# max      242.000000
# Name: duration, dtype: float64

# %%
data.duration.plot(kind='hist')

# %%
data.genre.value_counts().plot(kind="hist")
